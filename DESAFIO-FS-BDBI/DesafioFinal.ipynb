# %% [markdown]
# # Importando as bibliotecas e o arquivo csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/dados_rh (1).csv')

# %% [markdown]
# # 1A-  Quantas linhas e colunas temos no banco de dados?

# %%
print("Número de linhas:", df.shape[0])
print("Número de colunas:", df.shape[1])
# Out:
# Número de linhas: 1470
# Número de colunas: 35

# %% [markdown]
# **Resposta da Questão 1A** - A tabela contém exatamente 1470 linhas e 35 colunas

# %% [markdown]
# # 1B-  Existem dados nulos no banco?

# %%
print(df.isnull().sum())
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# **Resposta da Questão 1A-** O conjunto de dados não possui nenhum valor nulo.

# %% [markdown]
# # 1C- Tipo de dados que estão presentes no banco de dados

# %%
print(df.dtypes)
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# **Resposta da Questão 1C** - Existem dois tipos de dados presentes no banco de dados, são eles: objeto e inteiro

# %% [markdown]
# # 2. Agupamento de Dados e Plotagem de Gráficos

# %% [markdown]
# # 2A - Plote um gráfico de barras (bar) que exiba a quantidade de funcionários em cada setor (coluna Department)

# %%
df['Department'].value_counts().plot(kind='bar', color=['#483D8B'])
plt.title('Funcionários por Setor')
plt.xlabel('Setor')
plt.ylabel('Número de Funcionários')
plt.show()

# %% [markdown]
# # 2B - Plote um gráfico de linha (line) que exiba a quantidade de funcionários para cada nível de escolaridade (coluna Education)

# %%
df.groupby('Education')['EmployeeNumber'].count().plot(kind='line', color=['#4169E1'])
plt.title('Funcionários por Nível de Escolaridade')
plt.xlabel('Nível de Escolaridade')
plt.ylabel('Número de Funcionários')
plt.show()

# %% [markdown]
# **2C** - Plote um gráfico de torta/pizza (pie) que exiba a quantidade de funcionários que tem ou não algum atrito na empresa (coluna Attrition)

# %%
df['Attrition'].value_counts().plot(kind='pie')
plt.title('Funcionários com Atrito')
plt.show()
